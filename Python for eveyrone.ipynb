# %% [markdown]
# # CURSO PYTHON FOR EVERYONE
# Programas

# %%
##pimer programa

#Programa que transforma el numero de piso de estadar en inglaterra a usa
npiso=int(input("Que numero de piso quiere ir"))+1
print("su numero de piso es ",npiso)

# %%
def main():

    print("Hola esta es la calculadora de horas de trabajo")
    try:           #implementacion de try & except
        horas=float(input("ingresa nuemro de horas:"))
        rate=float(input("ingresa valor pay rate:"))
    except:
        print("error,porfavor ingresa un valor numerico")
        return   "intenta otra vez" #finaliza el programa

    payrate=horas*rate
    print("tu pay rate es: ",payrate)

main()

# %%
#Programa que imprime si un numero es menor que 10 o mayor que 20
#Imprime menor que 10 o mayor que 20

def main(): 
    x=int(input("ingrese el numero"))
    if x<10   :
        print("x menor ")
    elif  x> 20 : print("x mayor")

main()

# %%
#Programa que utiliza Try except

x=input("igresa un numero")
try:
    y=int(x)
except:
    y= -1
    
    
if y>0:
    print("good work")
else:
    print("not a number try again")
print(y)

# %%
tiny=min("hellowarld")
print(tiny)

# %%
#Implementacion de iterations structure
#Uso de while and for

n=int(input("ingrese un numero "))  # solicitia input de usuario

while n>0:  #define el loop  mientras que el numero sea mayor que 5 reptira las intruciones a continuacion
    print(n)  # 1.Imprime el valor de n
    n=n-1     #substrae 1 al valor de n
    
print("Done") #Imprime done al finalizar el loop 
print(n)      #Imprime el valor final de n

# %%
#loop infinito
def finito():
    x=5
    while x>5:
        print("leather")
        print("rinse")
    print("dry off")
    
def zloop():  #loop que no va ningun lugar
    x=0
    while x>0:
        print("leather")
        print("rinse")
    print("dry off")   
    
zloop()

# %%
#Uso de brake en un loop & continue

#def loop():
    #while True:
       # line=input("> ")
      #  if line== "done":
     #       break
    #    print(line)
        
   # print("done!thanks")    
    
#loop()

#loop con continue


while True:
    line=input("> ")
    if line[0]=="#":
        continue
    if line== "Done":
        break
    

print("done")

# %%
# Lista de frutas
#frutas = ["manzana", "banana", "cereza","123"]

# Iterar sobre cada fruta en la lista
#for x in frutas:
    #print(x)
    
    
#for i in [1,2,3,4,5]:
   # print(i)
#print('done')

friends=["josep","adrian","luis"]  #friens es la lista de nombres
for names in friends:              # se define la iteracion names se convierte ne la variable que va a iterar el listado
    print("happy new year",names)  # imprime la variable iterante + un string
print("Done")                      #Se imprime final del programa

# %%
n_m_grande=-1
for numero in [9,41,12,34,74,222,56,3,400]:
    if numero>n_m_grande:
        n_m_grande=numero
   
print("numero mas grande",n_m_grande)

# %%
#contador dentro de un loop

count=0
mayor=-1
for numeros in [9,10,32,1,3,8,343,23,30,3,20]:
    count=count+1
    if numeros>mayor:
        mayor=numeros
    print(count,numeros)
print("el numero mayor es ",mayor)

# %%
#suma los numeros de una lista y da el total
count=0
total=0
for num in [9,41,12,3,74,15]:
    count=count+1
    total=total+num

    print(count,total,num)
print(count,"total es:",total,",promedio es:",total/count)

# %%
#Programa de busqueda con la variable true and false
count=0
found=False 
for numeros in [9,41,12,3,74,15,3,10,23,21,25,65,3]:
    count=count+1
    if numeros==3:
        found=True
        
        break
    else :
        found=False    
    print(count,found,numeros)
print(found,count,)

# %%
count=0
total=0.0
while True:
    num=input("Introduzca un numero")
    if num=="done":
        break
    try:
        val=float(num)
    except:
        print("Entrada invalida")
        continue
    #print(val)
    count=count+1
    total=total+val
print(total,count,total/count)
print("done")

# %%
mini=None
maxi=0
val=0

while True:
    
    try:
        num=int(input("introdusca un numero"))
    except:
        
        if num=="done":
            break
        val=num

        print("error ingrese un numero")
        continue

        if val>maxi:
            maxi=val

        if mini is None or mini>val:
            mini=val


    
        
print("el numero mayor es",maxi)
#print("el numero menor es",mini)
#print("Termine")

# %%
#Programa que calcula salario bruto

def  calculo_salario():
    salario=0
    horas_xtras=0
    try:
        nhoras=int(input("Ingrese numero de horas!:"))
        tarifaxhoras=float(input("Ingrese tarifa por horas!:"))
        salario=nhoras*tarifaxhoras
        if nhoras>40:
            horas_xtras=nhoras-40
            nhoras=nhoras-horas_xtras
            salario=(nhoras*tarifaxhoras)+(tarifaxhoras*1.5)*(horas_xtras)

            print("Salario  es ",(salario))
            print("el numero de horas extras fueron" ,horas_xtras)   



    except:
        print("!error!, introdusca valores validos")

calculo_salario()

         #funcion round(redondea el valor)

# %%
#escribre el valor de la exprecion
#imprime el tipo del valor

ancho=17
alto=12

print(ancho/2)
print(type(ancho/2))

print(ancho/2.0)
print(type(ancho/2.0))

print(alto/3)
print(type(alto/3))

print(1+2*5)
print(type(1+2+5))

# %%
#programa que solicita al usuario temperatura
#convierte grados celsiuas a fahrenheit

tempcel=int(input("Ingrese temperatura en grados Celsius"))
tempfahrenheit=(tempcel*9/5)+32
print("la temperatura es",tempfahrenheit,"Grados Farhrenheit")

# %%
x = 3
y = 5

# Sin usar 'not'
print((x > y),end=' ' )    # Salida: False
print(x <= y)     # Salida: True

# Usando 'not'
print(not (x > y)) # Salida: True
print(not (x <= y)) # Salida: False

# %%
#Programa de calificacion

#funcion notas
def calcula_calificacion():
    #Entrada de usuario
    try:
        puntuacion=float(input("Introdusca Su Nota"))

    #Rando valido de notas  #if puntuacion > 0.0 and puntuacion <=10:
        if 0.0 <puntuacion  <=1.0:
        #Comparador de valores de notas
            if puntuacion>=0.9:
                print("Su nota es sobresaliente")
            elif puntuacion >=0.8:
                print("Su nota es Notable")
            elif puntuacion >=0.7:
                print("Su nota es Bien")
            elif puntuacion >=0.6:
                print("Su nota es suficiente")
            elif puntuacion <0.6:
                print("Su nota es Insuficiente")
        else:
            print("Eror!Puntiacion incorrecta")


    except:    
        print("Error ingrese valores numericos")

 #####################################################################   
import random 
    
t=[1,2,3]
random.choice(t)



calcula_calificacion()

# %%
import math


def muestra_dos_veces(x, y):
    suma=x+y
    return suma
    
  
    
muestra_dos_veces(1,2)
    
#############################
#funcion esteril realiza una accion pero no arroja un resultado

# %%
total = 0
for valor in [3, 41, 12, 9, 74, 15]:
    total = total +valor  #acumulador
print('Total: ', total)

# %%
num=0      #Define la variable num
lista=[]   #Define la variable lista es importa definir antes de comenzar el loop

while True:
    num=input("introduce numero")#itroduce numero
    if num=="done":              #controlo del bucle debe estar despues del input para darle control a la salida
        break                    #salida
    try:    
        fvl=float(num)
        lista.append(fvl)        #la tranformacion a floatante debe hacerse en dos variable separadas porque el la entrada brake y done estara dentro del mismo argument
        
    except:
        print('error')
        continue
    print(lista)
try:
    print("numero mayor es:",max(lista))
    print("numero menor es:",min(lista))
except:
    print("termine")

# %% [markdown]
# ####

# %%
num=None
count=0
suma=0
lista=[]
x=None
y=None

while True:
    num=input("Introdusca un numero :")
    if num=="fin":
        break
    try:
        fl=int(num)
    except:
        print("error !Dato no valido!")
        continue
        
    if x is None or fl>x:    #Define x como non y luego lo compara para 
                              #Determinar si es mayo y guardar ese valor como mayor 
        x=(fl)
    print(num,x)
    if y is None or fl<y:
        y=(fl)
    print(num,y)
    
    
    #print("antes",count)
 
  
        
print("numero mayor es:",x)        
print("numero menor es:",y)

# %%
int(3.99)
